# %%
import json
cadena=[]
base_datos={"tioxj":"hec"}
lista=[]
compra=[]
contraseña=0
i=0
a=0
with open('articulos.json','r') as f:
    lista=json.load(f)
    print(lista)

#//inicio de sesion: validacion de datos 
while i==0:
    a=input("Ingresa 'A'  para iniciar sesion 'B' para crear usuario o 'C' para salir :\n")
    if a == 'a' or a=='A':
        while i==0:
            ingreso=input("ingrese su usuario :\n")
            if ingreso in base_datos:
                contraseña=(input("ingrese su contraseña :\n"))
                if contraseña==base_datos.get(ingreso):
                    print("¡ingreso exitoso...!\n")
                    #creacion de nuevo producto
                    while i==0:
                        ingreso=input("Ingresa 'A' para crear articulo 'B' para buscar articulo 'C' para ventas 'D' para Regresar\n")
                        if ingreso=='a'or ingreso=='A':
                            diccionario={}
                            ar=input("Ingrese el nombre del Producto ")
                            pre=int(input("ingrese el precio "))
                            can=int(input("ingrese la cantidad "))
                            diccionario={}
                            diccionario["nombre"]=ar
                            diccionario["precio"]=pre
                            diccionario["cantidad"]=can
                            lista.append(diccionario)
                            print("el producto",ar," se guardo con el codigo :",lista.index(diccionario))
                            with open('articulos.json',"w") as f:
                                json.dump(lista, f)
                            
                                
                            
                        elif ingreso == 'b' or ingreso=='B':
                            articulo=int(input("ingrese el codigo del producto :"))
                            if lista[articulo] in lista:
                                print("Hay",lista[articulo]["cantidad"],"unidades de",lista[articulo]["nombre"])
                            elif lista[articulo] > len(lista):
                                print("el codigo no esta registrado")
                    
                        elif ingreso== 'c' or ingreso=='C':
                            print("Lista de productos ")
                            for x in range(0,len(lista)):
                                print ("code",x,lista[x])
                            while i==0:
                                opcion=input("ingrese 'A' para agregar producto 'B' Para confirmar compra 'C' para eliminar un producto 'D' Regresar :")
                                if opcion=='a':
                                    code=int(input("ingrese el codigo del producto :"))
                                    cant=int(input("ingrese la cantidad :"))
                                    if code in range(0,len(lista)):
                                        if cant <= lista[code]["cantidad"]:
                                            compra.append({"codigo":code,"nombre":lista[code]["nombre"],"compra":cant,"valor":lista[code]["precio"]*cant})

                                            print("Su carrito")
                                            for x in range(0,len(compra)):
                                                print (compra[x])
                                            
                                        else:
                                            print("Cantidad superior a las existentes")
                                            print("Hay",lista[code]["cantidad"],"unidades de",lista[code]["nombre"])
                                       
                                    else:
                                        print("El codigo no es valido")
                                elif opcion=='b' or opcion=='B':
                                    print("su carrito")
                                    for c in compra:
                                        lista[c["codigo"]]["cantidad"] -= c["compra"]
                                        
                                        
                                        
                                    
                                
                                elif opcion=='c' or opcion=='C':
                                    pre=input("ingrese el nombre del producto a eliminar")
                                    compra.pop(pre)
                                    print("eliminado")
                                    
                                    
                                
                                elif opcion=='d' or opcion=='D':
                                    break
                                else:
                                    print("Opcion no valida")
                        elif ingreso== 'd' or ingreso=='D':
                            break
                    
                        
                        else:
                            print("opcion no valida")
                        
                else:
                    print("contraseña incorrecta")
            elif ingreso not in base_datos:
                print("el usuario no esta registrado")
                break

            else:
                print("usuario o contraseña incorrectos")
    #//crea usuario
    elif a == 'b' or a=='B':
        nuevo_usuario=input("ingrese el nuevo usuario :")
        print("El usuario ",nuevo_usuario," sera guardado")
        nueva_contraseña=input("ingrese su nueva contraseña :")
        base_datos[nuevo_usuario]=nueva_contraseña
        cadena=json.dumps(base_datos)
        with open('datos.json',"a") as f:
            json.dump(cadena,f)
            f.write("\n")
        print("se a guardado correctamente")
        
        
    elif a == 'c' or a=='C':
        print("hasta pronto...")
        break
                        
      

#Crear un sistema de Inventario:
#El sistema debe tener login\\
#El sistema debe preguntar al inicio si quiere crear usuario o iniciar secion\\

#El sistema debe permitir la creacion de articulos nuevos
#Al crear un articulo nuevo el sistema debe preguntar ( Nombre, cantidad existente, Precio)
#Al crear un articulo nuevo el sistema debe asignarle un numero identificador

#El sistema debe permitir buscar articulos creados  y mostrar cuantos hay de dicho articulo

#El sistema debe tener la opcion de vender 
#Al sistema vender debe indicarsele los articulos que se quieren vender y que cantidad asi tambien como el nombre de a quien se le vende
#Al sistema vender articulos debe descontarlos del total actual
#Si no hay suficientes unidades del articulo seleccionado debe mostrar un error y no realizar ninguna venta
#Si al momento de vender todo sale bien debe indicar el precio total de la compra y preguntar si desea proceder
#Si se selecciona proceder  entonces se debe mostrar en pantalla una factura que contenga todos los articulos, el total de la compra,
#el nombre de la empresa y el nombre de quien compra
# Out:
# Ingresa 'A'  para iniciar sesion 'B' para crear usuario o 'C' para salir :
# a
# ingrese su usuario :
# tioxj
# ingrese su contraseña :
# hec
# ¡ingreso exitoso...!
#
# Ingresa 'A' para crear articulo 'B' para buscar articulo 'C' para ventas 'D' para Regresar
# a
# Ingrese el nombre del Producto yuca
# ingrese el precio 1500
# ingrese la cantidad 30
# el producto yuca  se guardo con el codigo : 0

# %%
import json

with open('test.json') as json_file:
    data = json.load(json_file)

print(data["usuarios"])

for p in data["productos"]:
    print(p["nombre"]+" - "+str(p["precio"])+ " - "+str(p["cantidad"]))

#Modificamos algo de la lista
data["productos"][0]["cantidad"] -= 5

with open('test.json', 'w') as outfile:
    json.dump(data, outfile)
# Out:
# {'name': 'jeyner', 'password': '123'}
# papa - 100 - 5
# yuca - 100 - 10

# %%
import json

# volcar datos a una variable 
base_datos={"usuario":"tioxj","contrasena":"hec"}
cadena=json.dumps(base_datos)

#escritura

with open('datos.json',"w") as f:
    json.dump(cadena, f)
    
#lectura
#volcar contenido 
with open('datos.json','r') as f:
    cadena=json.load(f)
    print(cadena)
# Out:
# {"usuario": "tioxj", "contrasena": "hec"}
